# %% [markdown]
# # Install

# %%
! pip install memory_profiler
# %load_ext memory_profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: memory_profiler in /data/home/bt211037/.local/lib/python3.9/site-packages (0.60.0)
# Requirement already satisfied: psutil in /share/apps/centos7/anaconda3/2021.11/lib/python3.9/site-packages (from memory_profiler) (5.8.0)

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearnex import patch_sklearn  # Speeds up sklearn with intel patch
patch_sklearn()  # Activate patch - changes sklearn imports below

from timeit import default_timer as timer # Time how long commands take
from sklearn.model_selection import train_test_split, StratifiedKFold  # test_train split, cross-validation

from sklearn.experimental import enable_iterative_imputer  # Iterative imputer experimental so need to enable it
from sklearn.impute import IterativeImputer  # Once enabled iterative imputer can be imported

from sklearn.linear_model import RidgeClassifier, BayesianRidge  # Imputation
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder  # Normalisation & Encoding
from imblearn.under_sampling import TomekLinks, RandomUnderSampler   # Undersampling
from imblearn.over_sampling import SMOTENC  # Oversampling
from sklearn.feature_selection import RFE, RFECV  # Recursive feature elimination - feature selection
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier  # RFE
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.svm import SVC
from imblearn.pipeline import Pipeline as imbpipeline

from sklearn.impute import KNNImputer
from sklearn.compose import ColumnTransformer

from sklearn.impute import SimpleImputer
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import validation_curve

import pickle
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# # Variables

# %%
# Number of cores being used 
n_jobs = 10

# %%
# Random State
random_state = 14

# %% [markdown]
# # General Functions

# %%
# Stopwatch to profile function runtimes
class Stopwatch:

    # Initiate constructor
    def __init__(self):
        self.start = timer()
        self.end = None
        self.runtime = None

    # Stop stopwatch
    def stop(self):
        self.end = timer()
        self.runtime = self.end - self.start
        return self.runtime

# %% [markdown]
# # Manual Feature Selection

# %%
# Read in data
df = pd.read_csv('/data/home/bt211037/dissertation/supervised_ML_data.tsv',
                   sep='\t', header=0, index_col=0)

# %%
# Get a list of the features
features = list(df.columns)

# %%
features
# Out:
# ['Weight method|x21_0_0',
#  'Spirometry method|x23_0_0',
#  'Year of birth|x34_0_0',
#  'Hand grip strength (left)|x46_0_0',
#  'Hand grip strength (right)|x47_0_0',
#  'Waist circumference|x48_0_0',
#  'Hip circumference|x49_0_0',
#  'Standing height|x50_0_0',
#  'Month of birth|x52_0_0',
#  'UK Biobank assessment centre|x54_0_0',
#  'Month of attending assessment centre|x55_0_0',
#  'Time since interview start at which blood pressure screen(s) shown|x96_0_0',
#  'Pulse rate automated reading|x102_0_0',
#  'Birth weight known|x120_0_0',
#  'Place of birth in UK - north co-ordinate|x129_0_0',
#  'Place of birth in UK - east co-ordinate|x130_0_0',
#  'Number of self-reported cancers|x134_0_0',
#  'Number of self-reported non-cancer illnesses|x135_0_0',
#  'Number of operations self-reported|x136_0_0',
#  'Number of treatments/medications taken|x137_0_0',
#  'Townsend deprivation index at recruitment|x189_0_0',
#  'Type of accommodation lived in|x670_0_0',
#  'Own or rent accommodation lived in|x680_0_0',
#  'Length of time at current address|x699_0_0',
#  'Number in household|x709_0_0',
#  'Number of vehicles in household|x728_0_0',
#  'Average total household income before tax|x738_0_0',
#  'Number of days/week walked 10+ minutes|x864_0_0',
#  'Duration of walks|x874_0_0',
#  'Number of days/week of moderate physical activity 10+ minutes|x884_0_0',
#  'Number of days/week of vigorous physical activity 10+ minutes|x904_0_0',
#  'Usual walking pace|x924_0_0',
#  'Frequency of stair climbing in last 4 weeks|x943_0_0',
#  'Frequency of friend/family visits|x1031_0_0',
#  'Time spend outdoors in summer|x1050_0_0',
#  'Time spent outdoors in winter|x1060_0_0',
#  'Time spent watching television (TV)|x1070_0_0',
#  'Time spent using computer|x1080_0_0',
#  'Time spent driving|x1090_0_0',
#  'Drive faster than motorway speed limit|x1100_0_0',
#  'Length of mobile phone use|x1110_0_0',
#  'Weekly usage of mobile phone in last 3 months|x1120_0_0',
#  'Hands-free device/speakerphone use with mobile phone in last 3 month|x1130_0_0',
#  'Difference in mobile phone use compared to two years previously|x1140_0_0',
#  'Usual side of head for mobile phone use|x1150_0_0',
#  'Sleep duration|x1160_0_0',
#  'Getting up in morning|x1170_0_0',
#  'Morning/evening person (chronotype)|x1180_0_0',
#  'Nap during day|x1190_0_0',
#  'Sleeplessness / insomnia|x1200_0_0',
#  'Snoring|x1210_0_0',
#  'Daytime dozing / sleeping (narcolepsy)|x1220_0_0',
#  'Current tobacco smoking|x1239_0_0',
#  'Past tobacco smoking|x1249_0_0',
#  'Smoking/smokers in household|x1259_0_0',
#  'Exposure to tobacco smoke at home|x1269_0_0',
#  'Exposure to tobacco smoke outside home|x1279_0_0',
#  'Cooked vegetable intake|x1289_0_0',
#  'Salad / raw vegetable intake|x1299_0_0',
#  'Fresh fruit intake|x1309_0_0',
#  'Dried fruit intake|x1319_0_0',
#  'Oily fish intake|x1329_0_0',
#  'Non-oily fish intake|x1339_0_0',
#  'Processed meat intake|x1349_0_0',
#  'Poultry intake|x1359_0_0',
#  'Beef intake|x1369_0_0',
#  'Lamb/mutton intake|x1379_0_0',
#  'Pork intake|x1389_0_0',
#  'Cheese intake|x1408_0_0',
#  'Milk type used|x1418_0_0',
#  'Spread type|x1428_0_0',
#  'Bread intake|x1438_0_0',
#  'Bread type|x1448_0_0',
#  'Cereal intake|x1458_0_0',
#  'Cereal type|x1468_0_0',
#  'Salt added to food|x1478_0_0',
#  'Tea intake|x1488_0_0',
#  'Coffee intake|x1498_0_0',
#  'Coffee type|x1508_0_0',
#  'Hot drink temperature|x1518_0_0',
#  'Water intake|x1528_0_0',
#  'Major dietary changes in the last 5 years|x1538_0_0',
#  'Variation in diet|x1548_0_0',
#  'Alcohol intake frequency.|x1558_0_0',
#  'Alcohol usually taken with meals|x1618_0_0',
#  'Alcohol intake versus 10 years previously|x1628_0_0',
#  'Skin colour|x1717_0_0',
#  'Ease of skin tanning|x1727_0_0',
#  'Childhood sunburn occasions|x1737_0_0',
#  'Hair colour (natural before greying)|x1747_0_0',
#  'Facial ageing|x1757_0_0',
#  'Father still alive|x1797_0_0',
#  'Mother still alive|x1835_0_0',
#  'Number of full brothers|x1873_0_0',
#  'Number of full sisters|x1883_0_0',
#  'Mood swings|x1920_0_0',
#  'Miserableness|x1930_0_0',
#  'Irritability|x1940_0_0',
#  'Sensitivity / hurt feelings|x1950_0_0',
#  'Fed-up feelings|x1960_0_0',
#  'Nervous feelings|x1970_0_0',
#  'Worrier / anxious feelings|x1980_0_0',
#  "Tense / 'highly strung'|x1990_0_0",
#  'Worry too long after embarrassment|x2000_0_0',
#  "Suffer from 'nerves'|x2010_0_0",
#  'Loneliness isolation|x2020_0_0',
#  'Guilty feelings|x2030_0_0',
#  'Risk taking|x2040_0_0',
#  'Frequency of depressed mood in last 2 weeks|x2050_0_0',
#  'Frequency of unenthusiasm / disinterest in last 2 weeks|x2060_0_0',
#  'Frequency of tenseness / restlessness in last 2 weeks|x2070_0_0',
#  'Frequency of tiredness / lethargy in last 2 weeks|x2080_0_0',
#  'Seen doctor (GP) for nerves anxiety tension or depression|x2090_0_0',
#  'Seen a psychiatrist for nerves anxiety tension or depression|x2100_0_0',
#  'Able to confide|x2110_0_0',
#  'Answered sexual history questions|x2129_0_0',
#  'Age first had sexual intercourse|x2139_0_0',
#  'Lifetime number of sexual partners|x2149_0_0',
#  'Ever had same-sex intercourse|x2159_0_0',
#  'Overall health rating|x2178_0_0',
#  'Long-standing illness disability or infirmity|x2188_0_0',
#  'Wears glasses or contact lenses|x2207_0_0',
#  'Age started wearing glasses or contact lenses|x2217_0_0',
#  'Other eye problems|x2227_0_0',
#  'Plays computer games|x2237_0_0',
#  'Hearing difficulty/problems|x2247_0_0',
#  'Hearing difficulty/problems with background noise|x2257_0_0',
#  'Use of sun/uv protection|x2267_0_0',
#  'Frequency of solarium/sunlamp use|x2277_0_0',
#  'Falls in the last year|x2296_0_0',
#  'Weight change compared with 1 year ago|x2306_0_0',
#  'Wheeze or whistling in the chest in last year|x2316_0_0',
#  'Chest pain or discomfort|x2335_0_0',
#  'Ever had bowel cancer screening|x2345_0_0',
#  'Diabetes diagnosed by doctor|x2443_0_0',
#  'Cancer diagnosed by doctor|x2453_0_0',
#  'Fractured/broken bones in last 5 years|x2463_0_0',
#  'Other serious medical condition/disability diagnosed by doctor|x2473_0_0',
#  'Taking other prescription medications|x2492_0_0',
#  'Result ranking|x3059_0_0',
#  'Acceptability of each blow result|x3061_0_0',
#  'Forced vital capacity (FVC)|x3062_0_0',
#  'Forced expiratory volume in 1-second (FEV1)|x3063_0_0',
#  'Peak expiratory flow (PEF)|x3064_0_0',
#  'Ordering of blows|x3065_0_0',
#  'Pace-maker|x3079_0_0',
#  'Contra-indications for spirometry|x3088_0_0',
#  'Caffeine drink within last hour|x3089_0_0',
#  'Used an inhaler for chest within last hour|x3090_0_0',
#  'Number of measurements made|x3137_0_0',
#  'Diastolic blood pressure automated reading|x4079_0_0',
#  'Systolic blood pressure automated reading|x4080_0_0',
#  'Method of measuring blood pressure|x4081_0_0',
#  'Qualifications|x6138_0_0',
#  'Gas or solid-fuel cooking/heating|x6139_0_0',
#  'How are people in household related to participant|x6141_0_0',
#  'Current employment status|x6142_0_0',
#  'Never eat eggs dairy wheat sugar|x6144_0_0',
#  'Illness injury bereavement stress in last 2 years|x6145_0_0',
#  'Attendance/disability/mobility allowance|x6146_0_0',
#  'Mouth/teeth dental problems|x6149_0_0',
#  'Medication for pain relief constipation heartburn|x6154_0_0',
#  'Vitamin and mineral supplements|x6155_0_0',
#  'Pain type(s) experienced in last month|x6159_0_0',
#  'Leisure/social activities|x6160_0_0',
#  'Types of transport used (excluding work)|x6162_0_0',
#  'Types of physical activity in last 4 weeks|x6164_0_0',
#  'Mineral and other dietary supplements|x6179_0_0',
#  'Interpolated Year when operation took place|x20010_0_0',
#  'Interpolated Age of participant when operation took place|x20011_0_0',
#  'Sitting height|x20015_0_0',
#  'Home location at assessment - east co-ordinate (rounded)|x20074_0_0',
#  'Home location at assessment - north co-ordinate (rounded)|x20075_0_0',
#  'Illnesses of father|x20107_0_0',
#  'Illnesses of mother|x20110_0_0',
#  'Illnesses of siblings|x20111_0_0',
#  'Smoking status|x20116_0_0',
#  'Alcohol drinker status|x20117_0_0',
#  'Home area population density - urban or rural|x20118_0_0',
#  'Neuroticism score|x20127_0_0',
#  'Spirometry QC measure|x20255_0_0',
#  'Forced expiratory volume in 1-second (FEV1) Z-score|x20256_0_0',
#  'Forced vital capacity (FVC) Z-score|x20257_0_0',
#  'FEV1/ FVC ratio Z-score|x20258_0_0',
#  'Body mass index (BMI)|x21001_0_0',
#  'Weight|x21002_0_0',
#  'Age when attended assessment centre|x21003_0_0',
#  'Genotype measurement batch|x22000_0_0',
#  'Genetic sex|x22001_0_0',
#  'Heterozygosity|x22003_0_0',
#  'Heterozygosity PCA corrected|x22004_0_0',
#  'Missingness|x22005_0_0',
#  'Genetic principal components_1|x22009_0_1',
#  'Genetic principal components_2|x22009_0_2',
#  'Genetic principal components_3|x22009_0_3',
#  'Genetic principal components_4|x22009_0_4',
#  'Genetic principal components_5|x22009_0_5',
#  'Genetic principal components_6|x22009_0_6',
#  'Genetic principal components_7|x22009_0_7',
#  'Genetic principal components_8|x22009_0_8',
#  'Genetic principal components_9|x22009_0_9',
#  'Genetic principal components_10|x22009_0_10',
#  'Genetic principal components_11|x22009_0_11',
#  'Genetic principal components_12|x22009_0_12',
#  'Genetic principal components_13|x22009_0_13',
#  'Genetic principal components_14|x22009_0_14',
#  'Genetic principal components_15|x22009_0_15',
#  'Genetic principal components_16|x22009_0_16',
#  'Genetic principal components_17|x22009_0_17',
#  'Genetic principal components_18|x22009_0_18',
#  'Genetic principal components_19|x22009_0_19',
#  'Genetic principal components_20|x22009_0_20',
#  'Genetic principal components_21|x22009_0_21',
#  'Genetic principal components_22|x22009_0_22',
#  'Genetic principal components_23|x22009_0_23',
#  'Genetic principal components_24|x22009_0_24',
#  'Genetic principal components_25|x22009_0_25',
#  'Genetic principal components_26|x22009_0_26',
#  'Genetic principal components_27|x22009_0_27',
#  'Genetic principal components_28|x22009_0_28',
#  'Genetic principal components_29|x22009_0_29',
#  'Genetic principal components_30|x22009_0_30',
#  'Genetic principal components_31|x22009_0_31',
#  'Genetic principal components_32|x22009_0_32',
#  'Genetic principal components_33|x22009_0_33',
#  'Genetic principal components_34|x22009_0_34',
#  'Genetic principal components_35|x22009_0_35',
#  'Genetic principal components_36|x22009_0_36',
#  'Genetic principal components_37|x22009_0_37',
#  'Genetic principal components_38|x22009_0_38',
#  'Genetic principal components_39|x22009_0_39',
#  'Genetic principal components_40|x22009_0_40',
#  'Genetic kinship to other participants|x22021_0_0',
#  'IPAQ activity group|x22032_0_0',
#  'Summed days activity|x22033_0_0',
#  'Summed minutes activity|x22034_0_0',
#  'Above moderate/vigorous recommendation|x22035_0_0',
#  'Above moderate/vigorous/walking recommendation|x22036_0_0',
#  'MET minutes per week for walking|x22037_0_0',
#  'MET minutes per week for moderate activity|x22038_0_0',
#  'MET minutes per week for vigorous activity|x22039_0_0',
#  'Summed MET minutes per week for all activity|x22040_0_0',
#  'Home location - east co-ordinate (rounded)|x22702_0_0',
#  'Weight|x23098_0_0',
#  'Body fat percentage|x23099_0_0',
#  'Whole body fat mass|x23100_0_0',
#  'Whole body fat-free mass|x23101_0_0',
#  'Whole body water mass|x23102_0_0',
#  'Body mass index (BMI)|x23104_0_0',
#  'Basal metabolic rate|x23105_0_0',
#  'Impedance of whole body|x23106_0_0',
#  'Impedance of leg (right)|x23107_0_0',
#  'Impedance of leg (left)|x23108_0_0',
#  'Impedance of arm (right)|x23109_0_0',
#  'Impedance of arm (left)|x23110_0_0',
#  'Leg fat percentage (right)|x23111_0_0',
#  'Leg fat mass (right)|x23112_0_0',
#  'Leg fat-free mass (right)|x23113_0_0',
#  'Leg predicted mass (right)|x23114_0_0',
#  'Leg fat percentage (left)|x23115_0_0',
#  'Leg fat mass (left)|x23116_0_0',
#  'Leg fat-free mass (left)|x23117_0_0',
#  'Leg predicted mass (left)|x23118_0_0',
#  'Arm fat percentage (right)|x23119_0_0',
#  'Arm fat mass (right)|x23120_0_0',
#  'Arm fat-free mass (right)|x23121_0_0',
#  'Arm predicted mass (right)|x23122_0_0',
#  'Arm fat percentage (left)|x23123_0_0',
#  'Arm fat mass (left)|x23124_0_0',
#  'Arm fat-free mass (left)|x23125_0_0',
#  'Arm predicted mass (left)|x23126_0_0',
#  'Trunk fat percentage|x23127_0_0',
#  'Trunk fat mass|x23128_0_0',
#  'Trunk fat-free mass|x23129_0_0',
#  'Trunk predicted mass|x23130_0_0',
#  'Nitrogen dioxide air pollution  2010|x24003_0_0',
#  'Nitrogen oxides air pollution  2010|x24004_0_0',
#  'Particulate matter air pollution (pm10)  2010|x24005_0_0',
#  'Particulate matter air pollution (pm2.5)  2010|x24006_0_0',
#  'Particulate matter air pollution (pm2.5) absorbance  2010|x24007_0_0',
#  'Particulate matter air pollution 2.5-10um  2010|x24008_0_0',
#  'Traffic intensity on the nearest road|x24009_0_0',
#  'Inverse distance to the nearest road|x24010_0_0',
#  'Traffic intensity on the nearest major road|x24011_0_0',
#  'Inverse distance to the nearest major road|x24012_0_0',
#  'Total traffic load on major roads|x24013_0_0',
#  'Close to major road|x24014_0_0',
#  'Sum of road length of major roads within 100m|x24015_0_0',
#  'Nitrogen dioxide air pollution  2005|x24016_0_0',
#  'Nitrogen dioxide air pollution  2006|x24017_0_0',
#  'Nitrogen dioxide air pollution  2007|x24018_0_0',
#  'Particulate matter air pollution (pm10)  2007|x24019_0_0',
#  'Average daytime sound level of noise pollution|x24020_0_0',
#  'Average evening sound level of noise pollution|x24021_0_0',
#  'Average night-time sound level of noise pollution|x24022_0_0',
#  'Average 24-hour sound level of noise pollution|x24024_0_0',
#  'Greenspace percentage buffer 1000m|x24500_0_0',
#  'Domestic garden percentage buffer 1000m|x24501_0_0',
#  'Water percentage buffer 1000m|x24502_0_0',
#  'Greenspace percentage buffer 300m|x24503_0_0',
#  'Domestic garden percentage buffer 300m|x24504_0_0',
#  'Water percentage buffer 300m|x24505_0_0',
#  'Natural environment percentage buffer 1000m|x24506_0_0',
#  'Natural environment percentage buffer 300m|x24507_0_0',
#  'Distance (Euclidean) to coast|x24508_0_0',
#  'Index of Multiple Deprivation (England)|x26410_0_0',
#  'Income score (England)|x26411_0_0',
#  'Employment score (England)|x26412_0_0',
#  'Health score (England)|x26413_0_0',
#  'Education score (England)|x26414_0_0',
#  'Housing score (England)|x26415_0_0',
#  'Crime score (England)|x26416_0_0',
#  'Living environment score (England)|x26417_0_0',
#  'White blood cell (leukocyte) count|x30000_0_0',
#  'Red blood cell (erythrocyte) count|x30010_0_0',
#  'Haemoglobin concentration|x30020_0_0',
#  'Haematocrit percentage|x30030_0_0',
#  'Mean corpuscular volume|x30040_0_0',
#  'Mean corpuscular haemoglobin|x30050_0_0',
#  'Mean corpuscular haemoglobin concentration|x30060_0_0',
#  'Red blood cell (erythrocyte) distribution width|x30070_0_0',
#  'Platelet count|x30080_0_0',
#  'Platelet crit|x30090_0_0',
#  'Mean platelet (thrombocyte) volume|x30100_0_0',
#  'Platelet distribution width|x30110_0_0',
#  'Lymphocyte count|x30120_0_0',
#  'Monocyte count|x30130_0_0',
#  'Neutrophill count|x30140_0_0',
#  'Eosinophill count|x30150_0_0',
#  'Basophill count|x30160_0_0',
#  'Nucleated red blood cell count|x30170_0_0',
#  'Lymphocyte percentage|x30180_0_0',
#  'Monocyte percentage|x30190_0_0',
#  'Neutrophill percentage|x30200_0_0',
#  'Eosinophill percentage|x30210_0_0',
#  'Basophill percentage|x30220_0_0',
#  'Nucleated red blood cell percentage|x30230_0_0',
#  'Reticulocyte percentage|x30240_0_0',
#  'Reticulocyte count|x30250_0_0',
#  'Mean reticulocyte volume|x30260_0_0',
#  'Mean sphered cell volume|x30270_0_0',
#  'Immature reticulocyte fraction|x30280_0_0',
#  'High light scatter reticulocyte percentage|x30290_0_0',
#  'High light scatter reticulocyte count|x30300_0_0',
#  'Total volume of urine samples held by UKB|x30394_0_0',
#  'Albumin|x30600_0_0',
#  'Alkaline phosphatase|x30610_0_0',
#  'Alanine aminotransferase|x30620_0_0',
#  'Apolipoprotein A|x30630_0_0',
#  'Apolipoprotein B|x30640_0_0',
#  'Aspartate aminotransferase|x30650_0_0',
#  'Direct bilirubin|x30660_0_0',
#  'Urea|x30670_0_0',
#  'Calcium|x30680_0_0',
#  'Cholesterol|x30690_0_0',
#  'Creatinine|x30700_0_0',
#  'C-reactive protein|x30710_0_0',
#  'Cystatin C|x30720_0_0',
#  'Gamma glutamyltransferase|x30730_0_0',
#  'Glucose|x30740_0_0',
#  'Glycated haemoglobin (HbA1c)|x30750_0_0',
#  'HDL cholesterol|x30760_0_0',
#  'IGF-1|x30770_0_0',
#  'LDL direct|x30780_0_0',
#  'Lipoprotein A|x30790_0_0',
#  'Phosphate|x30810_0_0',
#  'SHBG|x30830_0_0',
#  'Total bilirubin|x30840_0_0',
#  'Testosterone|x30850_0_0',
#  'Total protein|x30860_0_0',
#  'Triglycerides|x30870_0_0',
#  'Urate|x30880_0_0',
#  'Vitamin D|x30890_0_0',
#  'Records in HES inpatient operations dataset|x41149_0_0',
#  'Records in HES inpatient diagnoses dataset|x41234_0_0',
#  'Records in HES inpatient main dataset|x41259_0_0',
#  'Unadjusted T/S ratio|x22190_0_0',
#  'Adjusted T/S ratio|x22191_0_0',
#  'Z-adjusted T/S log|x22192_0_0',
#  'Creatinine (enzymatic) in urine|x30510_0_0',
#  'Potassium in urine|x30520_0_0',
#  'Sodium in urine|x30530_0_0',
#  'medication_cbi',
#  'thyroid_cancer']

# %%
# Create list of features to be removed 
bad_feats = [
    
    'Number of self-reported cancers|x134_0_0',
    'Number of operations self-reported|x136_0_0',
    'Number of treatments/medications taken|x137_0_0',
    'Cancer diagnosed by doctor|x2453_0_0',
    'Taking other prescription medications|x2492_0_0',
    'Other serious medical condition/disability diagnosed by doctor|x2473_0_0',
    'Records in HES inpatient operations dataset|x41149_0_0',
    'Records in HES inpatient diagnoses dataset|x41234_0_0',
    'Records in HES inpatient main dataset|x41259_0_0',
    
]

# %%
# Remove inappropriate features 
m_sel_features = [x for x in features if x not in bad_feats]

# %%
# new dataframe
no_leakage_data = df[m_sel_features]

# %%
# Save dataframe
no_leakage_data.to_csv('/data/home/bt211037/dissertation/no_leakage_data.tsv',
                      sep='\t',
                      index=True)
